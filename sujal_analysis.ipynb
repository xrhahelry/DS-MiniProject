# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

laptop = pd.read_csv("final_dataset.csv")

# %% [markdown]
# # High level overview of the data

# %%
print(laptop.info())
print(laptop.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1542 entries, 0 to 1541
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             1542 non-null   int64
#  1   brand             1542 non-null   object
#  2   model             1542 non-null   object
#  3   processor         1542 non-null   float64
#  4   ram memory        1542 non-null   int64
#  5   display size      1542 non-null   float64
#  6   storage capacity  1542 non-null   int64
#  7   cpu cores         1542 non-null   int64
#  8   graphics card     869 non-null    float64
#  9   rating            1542 non-null   float64
#  10  reviews           1542 non-null   int64
#  11  name              1542 non-null   object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 144.7+ KB
# None
#                price    processor   ram memory  display size  \
# count    1542.000000  1542.000000  1542.000000   1542.000000
# mean   123415.971466     5.474708    10.501946     14.918482
# std     74012.771404     1.561213     5.060022      0.895639
# min     25500.000000     2.000000     4.000000     10.500000
# 25%     73999.000000     5.000000     8.000000     14.000000
# 50%    104745.000000     5.000000     8.000000     15.600000
# 75%    149997.500000     7.000000    16.000000     15.600000
# max    555555.000000     9.000000    32.000000     17.300000
#
#        storage capacity    cpu cores  graphics card       rating      reviews
# count       1542.000000  1542.000000     869.000000  1542.000000  1542.000000
# mean         539.226978     6.563554    2584.752589     0.291051     0.234112
# std          268.877531     2.959303     792.293724     1.116840     2.209719
# min           64.000000     1.000000       0.000000     0.000000     0.000000
# 25%          256.000000     4.000000    2000.000000     0.000000     0.000000
# 50%          512.000000     6.000000    2800.000000     0.000000     0.000000
# 75%          512.000000     8.000000    3050.000000     0.000000     0.000000
# max         2048.000000    24.000000    4070.000000     5.000000    73.000000

# %% [markdown]
# # Ram Analysis

# %%
plt.figure(figsize=(14,10))
sns.boxplot(data=laptop, x='ram memory', y='price', hue='ram memory', palette='deep')
plt.legend([], [], frameon=False)
plt.show()
laptop['ram memory'].value_counts()
# Out:
# ram memory
# 8     915
# 16    451
# 4     136
# 32     29
# 12      5
# 24      5
# 6       1
# Name: count, dtype: int64

# %% [markdown]
# # Display Size Analysis

# %%
plt.figure(figsize=(14,10))
sns.boxplot(data=laptop, x='display size', y='price', hue='display size', palette='deep')
plt.legend([], [], frameon=False)
plt.show()
laptop['display size'].value_counts()
# Out:
# display size
# 15.6    831
# 14.0    519
# 13.3     76
# 16.0     45
# 15.0     19
# 13.6     11
# 14.1     11
# 17.3      8
# 16.1      8
# 13.5      5
# 11.6      3
# 14.5      2
# 16.2      1
# 10.5      1
# 12.0      1
# 17.0      1
# Name: count, dtype: int64

# %% [markdown]
# # Processor Analysis

# %%
plt.figure(figsize=(14,10))
sns.boxplot(data=laptop, x='processor', y='price', hue='processor', palette='deep')
plt.legend([], [], frameon=False)
plt.show()
laptop['processor'].value_counts()
# Out:
# processor
# 5.0    735
# 7.0    510
# 3.0    165
# 2.0     63
# 9.0     43
# 6.5     11
# 7.5     10
# 8.5      5
# Name: count, dtype: int64

# %% [markdown]
# # Storage Capacity Analysis

# %%
plt.figure(figsize=(14,10))
sns.boxplot(data=laptop, x='storage capacity', y='price', hue='storage capacity', palette='deep')
plt.legend([], [], frameon=False)
plt.show()
laptop['storage capacity'].value_counts()
# Out:
# storage capacity
# 512     860
# 256     375
# 1024    275
# 128      25
# 2048      5
# 64        2
# Name: count, dtype: int64

# %% [markdown]
# # Cpu Cores Analysis

# %%
plt.figure(figsize=(14,10))
sns.boxplot(data=laptop, x='cpu cores', y='price', hue='cpu cores', palette='deep')
plt.legend([], [], frameon=False)
plt.show()
laptop['cpu cores'].value_counts()
# Out:
# cpu cores
# 8     432
# 6     368
# 4     355
# 10    163
# 2     112
# 12     39
# 14     35
# 1      27
# 24      5
# 16      3
# 5       2
# 20      1
# Name: count, dtype: int64
