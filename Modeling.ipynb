# %%
import numpy as np
import pandas as pd

# %%
laptops = pd.read_csv("final_dataset.csv")

non_categorical_cols = ["id", "price", "brand", "model"]
categorical_cols = [
    "processor",
    "ram memory",
    "display size",
    "storage capacity",
    "cpu cores",
]
reorder = [
    "id",
    "brand",
    "model",
    "price",
    "processor",
    "ram memory",
    "display size",
    "storage capacity",
    "cpu cores",
]

df = laptops[reorder]

# %%
df_enc = pd.get_dummies(df, columns=categorical_cols)

cols = df_enc.columns.to_list()
one_hot_cols = list(set(cols) - set(non_categorical_cols))

for col in one_hot_cols:
    df_enc[col] = df_enc[col].apply(lambda x: int(x))

max = df_enc["price"].max()
min = df_enc["price"].min()
df_enc["price"] = df_enc["price"].apply(lambda x: (x - min) / (max - min))
df_enc["price"] = df_enc["price"].apply(lambda x: x * 100)
df_enc["price"] = df_enc["price"].astype(float).astype(int)

# %%
enc = df_enc.set_index("id")
not_enc = laptops.set_index("id")

choice = "5bffcd46c3"
vector1 = enc.loc[choice, :].to_numpy()[2:]
list1 = not_enc.loc[choice, :].tolist()[:-4]

for id, data in enc.iterrows():
    if id == choice:
        continue
    vector2 = enc.loc[id, :].to_numpy()[2:]
    distance = np.linalg.norm(vector1 - vector2)

    if distance <= 3:
        list2 = not_enc.loc[id, :].tolist()[:-4]
        print(distance)
        print(list1)
        print(list2)
        print("===========")
# Out:
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [126999, 'acer', 'Nitro 5', 5.0, 16, 15.6, 512, 8, 4050, 4.7, 3]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [126999, 'acer', 'Swift Go', 7.0, 16, 14.0, 512, 8, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'asus', 'Vivobook S', 5.0, 8, 14.0, 512, 6, 2000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129000, 'asus', 'ZENBOOK 14X', 7.0, 16, 14.1, 512, 8, 2050, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127777, 'asus', 'Vivobook 15', 7.0, 8, 15.6, 512, 8, 2800, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [122040, 'msi', 'Modern 14', 7.0, 8, 14.0, 512, 8, 2000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'dell', 'Latitude 3420', 5.0, 8, 14.0, 512, 4, 2050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [123000, 'asus', 'Vivobook Flip', 5.0, 8, 14.0, 512, 12, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127777, 'asus', '2023 Zenbook', 7.0, 16, 14.0, 1024, 8, 2000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127777, 'asus', 'Vivobook Flip', 7.0, 8, 14.0, 512, 8, 2800, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [128900, 'dell', 'Inspiron G15', 7.0, 16, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [121000, 'asus', 'Vivobook 14', 7.0, 8, 14.0, 512, 8, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127500, 'dell', 'Inspiron 16', 5.0, 8, 16.0, 512, 10, 2050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125500, 'dell', 'Inspiron 15', 5.0, 8, 15.6, 512, 6, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [133500, 'dell', 'Inspiron 16', 7.0, 16, 16.0, 512, 8, 2000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127500, 'dell', 'Inspiron 16', 5.0, 8, 16.0, 512, 10, 2050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Swift 3', 7.0, 16, 14.0, 512, 8, 2000, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [124500, 'asus', 'Vivobook Flip', 7.0, 8, 14.0, 512, 8, 2000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [123600, 'msi', 'Cyborg 15', 5.0, 16, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [136667, 'asus', 'TUF Gaming', 7.0, 8, 15.6, 512, 8, 2050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [123590, 'acer', 'Predator Triton', 7.0, 16, 14.0, 512, 8, 3060, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135990, 'dell', 'Latitude 5330', 7.0, 16, 13.3, 512, 10, 2800, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [124999, 'hp', '15s ', 5.0, 8, 15.6, 512, 4, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129000, 'acer', 'Nitro 5', 5.0, 8, 15.6, 512, 6, 3060, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135990, 'acer', 'Aspire 5', 5.0, 8, 14.0, 1024, 6, 0, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135000, 'asus', 'Zen Book', 5.0, 8, 14.0, 512, 4, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [124999, 'dell', 'Inspiron 14', 7.0, 16, 14.0, 1024, 8, 2800, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [118000, 'dell', 'Inspiron 7391', 5.0, 8, 13.3, 256, 4, 1000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'hp', 'Envy 13', 7.0, 8, 13.3, 512, 4, 2050, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129000, 'dell', 'Inspiron 5410', 5.0, 8, 14.0, 512, 1, 2800, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [132990, 'dell', 'Latitude 5330', 7.0, 16, 13.3, 256, 12, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [120000, 'asus', 'ZenBook Q507IQ', 7.0, 8, 15.6, 256, 8, 2000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [118000, 'dell', 'Inspiron 7391', 5.0, 8, 13.3, 256, 4, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [118000, 'dell', 'Latitude 13inch', 5.0, 8, 13.3, 256, 4, 2800, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129000, 'dell', 'INSPIRON 5510', 5.0, 8, 15.6, 256, 6, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Swift 3', 7.0, 16, 14.0, 512, 8, 1000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [120000, 'asus', 'Zenbook Q507Iq', 7.0, 8, 15.0, 256, 8, 2000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [131111, 'asus', 'Vivobook X415Ep', 7.0, 8, 14.0, 512, 8, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'asus', 'TUF F15', 5.0, 8, 15.6, 512, 4, 1650, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'asus', 'Expertbook B1400', 7.0, 32, 14.0, 256, 10, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135000, 'hp', 'Laptop 15s', 7.0, 8, 15.6, 512, 4, 2800, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [136000, 'asus', 'ZenBook 14X', 7.0, 8, 14.5, 512, 14, 2050, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127777, 'asus', 'Vivobook X1502Za', 7.0, 8, 15.6, 512, 8, 1000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [128000, 'hp', 'Envy 13', 7.0, 8, 13.3, 512, 4, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135000, 'msi', 'Modern 14', 5.0, 8, 14.0, 512, 4, 1400, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [133000, 'asus', 'VIVOBOOK E1404G', 3.0, 8, 14.0, 256, 4, 1000, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [121000, 'acer', 'Aspire 3', 7.0, 8, 15.6, 256, 10, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'lenovo', 'IdeaPad 3', 5.0, 8, 15.6, 512, 4, 1000, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Swift 2021', 7.0, 8, 13.3, 512, 4, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125990, 'dell', 'Vostro 3510', 7.0, 8, 15.6, 512, 4, 1300, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [124999, 'hp', 'Pavilion Laptop', 5.0, 8, 14.0, 512, 2, 2050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [122000, 'acer', 'Swift 3', 7.0, 16, 14.0, 1024, 8, 1000, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135000, 'asus', 'ZenBook 13', 5.0, 8, 13.3, 512, 4, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [120999, 'asus', 'Zenbook 14', 7.0, 16, 14.0, 512, 8, 2000, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'asus', 'Vivobook S435', 7.0, 8, 14.0, 512, 4, 1000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'lenovo', 'IdeaPad 1', 7.0, 8, 14.0, 512, 8, 2800, 0.0, 0]
# ===========
# 2.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129990, 'lenovo', 'Yoga 6', 7.0, 8, 13.3, 1024, 8, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [121000, 'dell', 'Inspiron 5400', 7.0, 8, 14.0, 512, 4, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [122000, 'asus', 'ZenBook 14', 5.0, 8, 14.0, 512, 6, 2800, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'acer', 'Swift 5', 7.0, 8, 14.0, 512, 4, 2800, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129000, 'hp', 'Omen 15', 7.0, 8, 15.6, 1024, 8, 1660, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [122222, 'asus', '2023 Zenbook', 5.0, 8, 14.0, 512, 6, 1000, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'msi', 'GF63 9SCSR', 5.0, 8, 15.6, 256, 6, 1000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [126999, 'acer', 'Nitro V', 5.0, 8, 15.6, 512, 8, 4050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [121212, 'acer', 'Nitro 5', 7.0, 16, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'hp', 'OMEN 15', 7.0, 16, 15.6, 1024, 8, 1660, 0.0, 0]
# ===========
# 1.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'apple', 'Macbook Air', 6.5, 8, 13.3, 256, 8, 2500, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [135000, 'acer', 'Predator Helios', 7.0, 8, 15.6, 1024, 8, 2060, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129000, 'acer', 'Nitro 5', 7.0, 16, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'hp', 'Omen 16', 7.0, 16, 15.6, 512, 8, 3060, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [131990, 'acer', 'Nitro 5', 7.0, 8, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [123390, 'hp', 'Victus 15', 7.0, 16, 15.6, 1024, 8, 3050, 0.0, 0]
# ===========
# 2.23606797749979
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [132999, 'lenovo', 'LOQ 15APH8', 7.0, 8, 15.6, 256, 8, 4050, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'msi', 'Katana GF66', 5.0, 16, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Nitro 5', 7.0, 8, 15.6, 512, 8, 1650, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Nitro 5', 5.0, 8, 15.6, 1024, 6, 3050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Nitro 5', 5.0, 8, 15.6, 512, 10, 3050, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [129999, 'acer', 'Nitro 5', 7.0, 16, 15.6, 512, 8, 1650, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [124000, 'acer', 'Nitro 5', 7.0, 8, 15.6, 1024, 8, 1650, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [134999, 'acer', 'nitro 5', 5.0, 8, 15.0, 1024, 6, 4050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [132000, 'acer', 'NITRO V15', 5.0, 8, 15.6, 512, 6, 4050, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'acer', 'Nitro 5', 7.0, 8, 15.6, 512, 8, 1650, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [131999, 'asus', 'Tuf Fx505dt', 5.0, 8, 15.6, 512, 6, 1650, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'acer', 'Nitro 5', 5.0, 8, 15.6, 512, 6, 1650, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'NITRO 5', 5.0, 8, 14.0, 512, 6, 3050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125999, 'asus', ' ', 5.0, 8, 15.6, 1024, 6, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [122000, 'asus', 'TUF F15', 5.0, 8, 15.6, 512, 6, 1650, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [128000, 'acer', 'Nitro 5', 5.0, 8, 15.6, 256, 6, 3050, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [131990, 'acer', 'Nitro 5', 7.0, 8, 15.6, 1024, 8, 3050, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [128000, 'acer', 'Nitro 5', 5.0, 8, 15.6, 512, 4, 1650, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [130000, 'acer', 'nitro 5', 5.0, 8, 15.6, 512, 8, 3050, 0.0, 0]
# ===========
# 2.8284271247461903
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127777, 'asus', 'Tuf Gaming', 5.0, 8, 15.6, 512, 6, 1650, 0.0, 0]
# ===========
# 2.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [127999, 'hp', 'Envy x360', 7.0, 8, 14.0, 256, 8, 1000, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [132500, 'dell', 'Latitude 5430', 5.0, 8, 14.0, 512, 4, 2800, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [133000, 'lenovo', 'LOQ 15APH8', 7.0, 8, 15.6, 512, 8, 4050, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [139990, 'lenovo', 'YOGA 6', 7.0, 8, 13.3, 256, 8, 2000, 0.0, 0]
# ===========
# 2.449489742783178
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [128500, 'acer', 'Nitro V', 5.0, 8, 15.6, 512, 8, 4050, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [134500, 'acer', 'Nitro 16', 5.0, 16, 15.6, 512, 8, 4050, 0.0, 0]
# ===========
# 2.6457513110645907
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [134999, 'acer', 'Nitro 5', 5.0, 8, 15.6, 512, 8, 4060, 0.0, 0]
# ===========
# 3.0
# [129900, 'apple', 'MacBook Air', 6.5, 8, 13.3, 256, 8, 2500, 4.8, 73]
# [125000, 'acer', 'Nitro 16', 5.0, 16, 16.0, 512, 8, 4050, 0.0, 0]
# ===========
